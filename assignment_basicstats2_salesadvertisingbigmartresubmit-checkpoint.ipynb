# %%
                                     #SALES ADVERTISING BIGMART PROJECT




#Task 1
#a
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import sklearn.linear_model as skl_lm
# %matplotlib inline
from sklearn import datasets,linear_model
from sklearn.linear_model import SGDRegressor,LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import scale

# %%
#Task 1
#a & b
df_marketing = pd.read_csv('SalesBasedOnAdvertising.csv')
df_marketing
#from the above it can be seen that there are 204-rows and 5-columns
# Out:
#      Sno     TV  radio  newspaper  sales
# 0      1  219.0    NaN       34.5   48.9
# 1      2  230.1   37.8       69.2   22.1
# 2      3   44.5   39.3       45.1   10.4
# 3      4   17.2   45.9       69.3    9.3
# 4      5  151.5   41.3       58.5   18.5
# 5      6  180.8   10.8       58.4   12.9
# 6      7    8.7   48.9       75.0    7.2
# 7      8   57.5   32.8       23.5   11.8
# 8      9  120.2   19.6       11.6   13.2
# 9     10    8.6    2.1        1.0    4.8
# 10    11  199.8    2.6       21.2   10.6
# 11    12   66.1    5.8       24.2    8.6
# 12    13  214.7   24.0        4.0   17.4
# 13    14   23.8   35.1       65.9    9.2
# 14    15   97.5    7.6        7.2    9.7
# 15    16  204.1   32.9       46.0   19.0
# 16    17  195.4   47.7       52.9   22.4
# 17    18   67.8   36.6      114.0   12.5
# 18    19  281.4   39.6       55.8   24.4
# 19    20   69.2   20.5       18.3   11.3
# 20    21  147.3   23.9       19.1   14.6
# 21    22  218.4   27.7       53.4   18.0
# 22    23  237.4    5.1       23.5   12.5
# 23    24   13.2   15.9       49.6    5.6
# 24    25  228.3   16.9       26.2   15.5
# 25    26   62.3   12.6       18.3    9.7
# 26    27  262.9    3.5       19.5   12.0
# 27    28  142.9   29.3       12.6   15.0
# 28    29  240.1   16.7       22.9   15.9
# 29    30  248.8   27.1       22.9   18.9
# ..   ...    ...    ...        ...    ...
# 174  175   50.0   11.6       18.4    8.4
# 175  176  164.5   20.9       47.4   14.5
# 176  177   19.6   20.1       17.0    7.6
# 177  178  168.4    7.1       12.8   11.7
# 178  179  222.4    3.4       13.1   11.5
# 179  180  276.9   48.9       41.8   27.0
# 180  181  248.4   30.2       20.3   20.2
# 181  182  170.2    7.8       35.2   11.7
# 182  183  276.7    2.3       23.7   11.8
# 183  184  165.6   10.0       17.6   12.6
# 184  185  156.6    2.6        8.3   10.5
# 185  186  218.5    5.4       27.4   12.2
# 186  187   56.2    5.7       29.7    8.7
# 187  188  287.6   43.0       71.8   26.2
# 188  189  253.8   21.3       30.0   17.6
# 189  190  205.0   45.1       19.6   22.6
# 190  191  139.5    2.1       26.6   10.3
# 191  192  191.1   28.7       18.2   17.3
# 192  193  286.0   13.9        3.7   15.9
# 193  194   18.7   12.1       23.4    6.7
# 194  195   39.5   41.1        5.8   10.8
# 195  196   75.5   10.8        6.0    9.9
# 196  197   17.2    4.1       31.6    5.9
# 197  198  166.8   42.0        3.6   19.6
# 198  199  149.7   35.6        6.0   17.3
# 199  200   38.2    3.7       13.8    7.6
# 200  201   94.2    4.9        8.1    9.7
# 201  202  177.0    9.3        6.4   12.8
# 202  203  283.6   42.0       66.2   25.5
# 203  204  232.1    8.6        8.7   13.4
#
# [204 rows x 5 columns]

# %%
#task1
#c

df_marketing.info()
#in the following datatset two types of datatypes are present 1)integer 2)float
#memory usage og the dataset is 8KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 5 columns):
# Sno          204 non-null int64
# TV           204 non-null float64
# radio        203 non-null float64
# newspaper    204 non-null float64
# sales        204 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 8.0 KB

# %%
df_marketing.describe()
#FROM THE STATISTIC WE CAN SAY THAT THE 
#THE MINIMUM SALES OF TV RADIO NEWSPAPER IS ALOMOST ZERO
#THE MAXIMUM SALES OF TV RADIO NEWSPAPER IS 296,49.6,114 RESPECTIVELY
# their standard 
#deviation are:-86.062,14.810,21.711,5.905 'the standard deviation tells a quantity expressing by how much the members of 
#a group differ from the mean value for the group'
#the range of the mean raise to (13,147) and their standard range raise to (4,87).
# Out:
#               Sno          TV       radio   newspaper       sales
# count  204.000000  204.000000  203.000000  204.000000  204.000000
# mean   102.500000  146.602451   23.122167   30.712255   14.020588
# std     59.033889   86.062496   14.810692   21.731852    5.905251
# min      1.000000    0.000000    0.000000    0.300000    0.000000
# 25%     51.750000   72.700000    9.950000   12.875000   10.250000
# 50%    102.500000  149.750000   22.300000   26.050000   12.900000
# 75%    153.250000  218.625000   36.400000   45.100000   17.400000
# max    204.000000  296.400000   49.600000  114.000000   48.900000

# %%
type(df_marketing)
#PANDAS DATAFRAME
# Out:
# pandas.core.frame.DataFrame

# %%
df_marketing.cov() 
#relationaship between each pair of the object is shown
#covariance is a measure of the relationship between to random variance
# Out:
#                    Sno           TV       radio   newspaper       sales
# Sno        3485.000000    45.423399  -97.290594 -197.101724  -34.183251
# TV           45.423399  7406.753245   79.314771   74.000216  369.128619
# radio       -97.290594    79.314771  219.356585  111.707667   45.836834
# newspaper  -197.101724    74.000216  111.707667  472.273396   23.763983
# sales       -34.183251   369.128619   45.836834   23.763983   34.871988

# %%
df_marketing.corr() 
#relation between two variable
#the correlation coefficient that indicates the strength of the relationship between two variable"""
# Out:
#                 Sno        TV     radio  newspaper     sales
# Sno        1.000000  0.008941 -0.111821  -0.153636 -0.098056
# TV         0.008941  1.000000  0.062181   0.039566  0.726316
# radio     -0.111821  0.062181  1.000000   0.346235  0.574775
# newspaper -0.153636  0.039566  0.346235   1.000000  0.185176
# sales     -0.098056  0.726316  0.574775   0.185176  1.000000

# %%
df_marketing.skew() 
#Skewness is a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean.
# Out:
# Sno          0.000000
# TV          -0.076086
# radio        0.109375
# newspaper    0.883296
# sales        1.159119
# dtype: float64

# %%
#task1
#d
df_marketing.isnull()
df_marketing[df_marketing['sales']==0]
df_marketing= df_marketing.drop(df_marketing.index[[99,123]])
df_marketing
#as row 99 and 123 contain zero value
#checking null value or not
#contain both null and not null
# Out:
#      Sno     TV  radio  newspaper  sales
# 0      1  219.0    NaN       34.5   48.9
# 1      2  230.1   37.8       69.2   22.1
# 2      3   44.5   39.3       45.1   10.4
# 3      4   17.2   45.9       69.3    9.3
# 4      5  151.5   41.3       58.5   18.5
# 5      6  180.8   10.8       58.4   12.9
# 6      7    8.7   48.9       75.0    7.2
# 7      8   57.5   32.8       23.5   11.8
# 8      9  120.2   19.6       11.6   13.2
# 9     10    8.6    2.1        1.0    4.8
# 10    11  199.8    2.6       21.2   10.6
# 11    12   66.1    5.8       24.2    8.6
# 12    13  214.7   24.0        4.0   17.4
# 13    14   23.8   35.1       65.9    9.2
# 14    15   97.5    7.6        7.2    9.7
# 15    16  204.1   32.9       46.0   19.0
# 16    17  195.4   47.7       52.9   22.4
# 17    18   67.8   36.6      114.0   12.5
# 18    19  281.4   39.6       55.8   24.4
# 19    20   69.2   20.5       18.3   11.3
# 20    21  147.3   23.9       19.1   14.6
# 21    22  218.4   27.7       53.4   18.0
# 22    23  237.4    5.1       23.5   12.5
# 23    24   13.2   15.9       49.6    5.6
# 24    25  228.3   16.9       26.2   15.5
# 25    26   62.3   12.6       18.3    9.7
# 26    27  262.9    3.5       19.5   12.0
# 27    28  142.9   29.3       12.6   15.0
# 28    29  240.1   16.7       22.9   15.9
# 29    30  248.8   27.1       22.9   18.9
# ..   ...    ...    ...        ...    ...
# 174  175   50.0   11.6       18.4    8.4
# 175  176  164.5   20.9       47.4   14.5
# 176  177   19.6   20.1       17.0    7.6
# 177  178  168.4    7.1       12.8   11.7
# 178  179  222.4    3.4       13.1   11.5
# 179  180  276.9   48.9       41.8   27.0
# 180  181  248.4   30.2       20.3   20.2
# 181  182  170.2    7.8       35.2   11.7
# 182  183  276.7    2.3       23.7   11.8
# 183  184  165.6   10.0       17.6   12.6
# 184  185  156.6    2.6        8.3   10.5
# 185  186  218.5    5.4       27.4   12.2
# 186  187   56.2    5.7       29.7    8.7
# 187  188  287.6   43.0       71.8   26.2
# 188  189  253.8   21.3       30.0   17.6
# 189  190  205.0   45.1       19.6   22.6
# 190  191  139.5    2.1       26.6   10.3
# 191  192  191.1   28.7       18.2   17.3
# 192  193  286.0   13.9        3.7   15.9
# 193  194   18.7   12.1       23.4    6.7
# 194  195   39.5   41.1        5.8   10.8
# 195  196   75.5   10.8        6.0    9.9
# 196  197   17.2    4.1       31.6    5.9
# 197  198  166.8   42.0        3.6   19.6
# 198  199  149.7   35.6        6.0   17.3
# 199  200   38.2    3.7       13.8    7.6
# 200  201   94.2    4.9        8.1    9.7
# 201  202  177.0    9.3        6.4   12.8
# 202  203  283.6   42.0       66.2   25.5
# 203  204  232.1    8.6        8.7   13.4
#
# [202 rows x 5 columns]

# %%
df_marketing= df_marketing.drop(df_marketing.index[[97,121]])

df_marketing=df_marketing[df_marketing['sales'].notnull()]
#dropped the complete row where sales data is null

# %%
df_marketing.isnull().sum()
df_marketing.notnull().sum().mean()
#count total no. of null values
# Out:
# 199.8

# %%
df_marketing['radio'].fillna(199,inplace=True)
#replace the null value with average of total n. of null value
#here since only one null value , i hve taken the average as 200

# %%
#e
df_marketing
#as there is no null value in the sales column so the no. of rows and coulumn are unchanged
# Out:
#      Sno     TV  radio  newspaper  sales
# 0      1  219.0  199.0       34.5   48.9
# 1      2  230.1   37.8       69.2   22.1
# 2      3   44.5   39.3       45.1   10.4
# 3      4   17.2   45.9       69.3    9.3
# 4      5  151.5   41.3       58.5   18.5
# 5      6  180.8   10.8       58.4   12.9
# 6      7    8.7   48.9       75.0    7.2
# 7      8   57.5   32.8       23.5   11.8
# 8      9  120.2   19.6       11.6   13.2
# 9     10    8.6    2.1        1.0    4.8
# 10    11  199.8    2.6       21.2   10.6
# 11    12   66.1    5.8       24.2    8.6
# 12    13  214.7   24.0        4.0   17.4
# 13    14   23.8   35.1       65.9    9.2
# 14    15   97.5    7.6        7.2    9.7
# 15    16  204.1   32.9       46.0   19.0
# 16    17  195.4   47.7       52.9   22.4
# 17    18   67.8   36.6      114.0   12.5
# 18    19  281.4   39.6       55.8   24.4
# 19    20   69.2   20.5       18.3   11.3
# 20    21  147.3   23.9       19.1   14.6
# 21    22  218.4   27.7       53.4   18.0
# 22    23  237.4    5.1       23.5   12.5
# 23    24   13.2   15.9       49.6    5.6
# 24    25  228.3   16.9       26.2   15.5
# 25    26   62.3   12.6       18.3    9.7
# 26    27  262.9    3.5       19.5   12.0
# 27    28  142.9   29.3       12.6   15.0
# 28    29  240.1   16.7       22.9   15.9
# 29    30  248.8   27.1       22.9   18.9
# ..   ...    ...    ...        ...    ...
# 174  175   50.0   11.6       18.4    8.4
# 175  176  164.5   20.9       47.4   14.5
# 176  177   19.6   20.1       17.0    7.6
# 177  178  168.4    7.1       12.8   11.7
# 178  179  222.4    3.4       13.1   11.5
# 179  180  276.9   48.9       41.8   27.0
# 180  181  248.4   30.2       20.3   20.2
# 181  182  170.2    7.8       35.2   11.7
# 182  183  276.7    2.3       23.7   11.8
# 183  184  165.6   10.0       17.6   12.6
# 184  185  156.6    2.6        8.3   10.5
# 185  186  218.5    5.4       27.4   12.2
# 186  187   56.2    5.7       29.7    8.7
# 187  188  287.6   43.0       71.8   26.2
# 188  189  253.8   21.3       30.0   17.6
# 189  190  205.0   45.1       19.6   22.6
# 190  191  139.5    2.1       26.6   10.3
# 191  192  191.1   28.7       18.2   17.3
# 192  193  286.0   13.9        3.7   15.9
# 193  194   18.7   12.1       23.4    6.7
# 194  195   39.5   41.1        5.8   10.8
# 195  196   75.5   10.8        6.0    9.9
# 196  197   17.2    4.1       31.6    5.9
# 197  198  166.8   42.0        3.6   19.6
# 198  199  149.7   35.6        6.0   17.3
# 199  200   38.2    3.7       13.8    7.6
# 200  201   94.2    4.9        8.1    9.7
# 201  202  177.0    9.3        6.4   12.8
# 202  203  283.6   42.0       66.2   25.5
# 203  204  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df_marketing.describe()
#a little change has been occured in the 25 and 50 percentile of the RADIO column
# Out:
#               Sno          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   102.325000  147.821000   24.092000   30.454500   14.130000
# std     59.585666   85.729607   19.336105   21.443385    5.852483
# min      1.000000    0.700000    0.000000    0.300000    0.000000
# 25%     50.750000   74.375000    9.975000   12.875000   10.300000
# 50%    102.500000  150.650000   22.900000   26.050000   12.900000
# 75%    154.250000  219.200000   36.525000   44.500000   17.450000
# max    204.000000  296.400000  199.000000  114.000000   48.900000

# %%
#task2
#a
plt.boxplot(df_marketing['TV'])
plt.show
#so from the box plot of TV sales we can that the 
#mean is 150
#minimum sale is zero
#maximaum sale is 300
#here the whisker determine the range that is(0,300)
#25 percentile is approx 70
#75 percentileis approx 218
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.boxplot(df_marketing['radio'])
plt.show
#so from the box plot of radio sales we can that the 
#mean is 22
#minimum sale is zero
#maximaum sale is 200
#here the whisker determine the range that is(0,200)
#25 percentile is approx 10
#75 percentileis approx 35
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.boxplot(df_marketing['newspaper'])
plt.show
#so from the box plot of newspaper sales we can that the 
#mean is 30
#minimum sale is 0
#maximaum sale is 114
#here the whisker determine the range that is(0,114)
#25 percentile is approx 12
#75 percentileis approx 45
#some outlier value are also present
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.boxplot(df_marketing['sales'])
plt.show
#so from the box plot of  sales we can that the 
#mean is 14
#minimum sale is zero
#maximaum sale is 49
#here the whisker determine the range that is(0,25)
#25 percentile is approx 10
#75 percentileis appr 17
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#task2
#b

# %%
fig=plt.figure(figsize=(13,8))
ax1=fig.add_subplot(2,2,1)
sns.boxplot(data=df_marketing,ax=ax1)
ax1.set_title("BOX PLOT")
ax2=fig.add_subplot(2,2,2)
sns.lineplot(data=df_marketing,ax=ax2)

ax2.set_title("LINE PLOT")
ax2.set_xlabel('catagories')
ax2.set_ylabel('data')
plt.legend(loc='best') 

plt.show()

# %%
#TASK3
#a
#in order to predict the sales based on marketing expenses we find independent and dependent variables
#so in the following data set Sales is the dependent variable for which we are going to create different model 
#so different model can be used 1)histogram 2)line charts 3)boxplot
plt.hist(df_marketing['sales'],bins=15)
plt.show()

# %%
#from the above box histogram we can see that more area is concentrated in the rnage of (0,28)
#max sale is 48
#For categorical variables, bar charts and frequency counts are the natural counterparts to histograms. Now is time to look 
#at the variables that contain some insight on the assumptions previously made.
#There seems to be the sales based on marketing expenses same to certain variable price i.e 1. But after that Most of 
#the independent and depedent variables are varies due to the gap of correlation and it seem to be either Small and Big or medium
#but larger than the count level 1.

# %%
#b
sns.distplot(df_marketing['sales'],kde=True)
# Out:
# C:\ProgramData\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#this plot shows how commom a specific sales is
#KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable.##
#It depicts the probability density at different values in a continuous variable.
#As we have plot a single graph for multiple samples which helps in more efficient data visualization.
#so from plot we conclude that sales increasing sharply for independent variable but after that decreaases as well in same manner

# %%
#task4
#a
plt.scatter(df_marketing['TV'],df_marketing['sales'])
plt.xlabel("tv expenditure")
plt.ylabel("sales")
plt.show()
#as we can see with the increse in expenditure on tv, the sales is also incresing

# %%
#b
fig=plt.figure(figsize=(13,8))
ax1=fig.add_subplot(3,3,1)
ax1.scatter(df_marketing['TV'],df_marketing['sales'],color='seagreen')
ax1.set_title("sales vs TV advertising",fontsize=20)
ax1.set_xlabel('tv advertisng')
ax1.set_ylabel('sales')
ax2=fig.add_subplot(3,3,2)
ax2.scatter(df_marketing['radio'],df_marketing['sales'],color='darkgreen')
ax2.set_xlabel('radio advertising')
ax2.set_ylabel('sales')
ax2.set_title("sales vs radio advertising",fontsize=20)
ax3=fig.add_subplot(3,3,3)
ax3.scatter(df_marketing['newspaper'],df_marketing['sales'],color='black')
ax3.set_xlabel('newspaper advertising')
ax3.set_ylabel('sales')
ax3.set_title("sales vs newspaper advertising",fontsize=20)
# Out:
# Text(0.5, 1.0, 'sales vs newspaper advertising')

# %%
#c
g=sns.pairplot(df_marketing,size=6,aspect=0.9,x_vars=['TV','radio','newspaper'],y_vars=['sales'])
g.map(plt.scatter);
# Out:
# C:\ProgramData\Anaconda\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
# 192  193  286.0   13.9        3.7   15.9      303.6
# 193  194   18.7   12.1       23.4    6.7       54.2
# 194  195   39.5   41.1        5.8   10.8       86.4
# 195  196   75.5   10.8        6.0    9.9       92.3
# 196  197   17.2    4.1       31.6    5.9       52.9
# 197  198  166.8   42.0        3.6   19.6      212.4
# 198  199  149.7   35.6        6.0   17.3      191.3
# 199  200   38.2    3.7       13.8    7.6       55.7
# 200  201   94.2    4.9        8.1    9.7      107.2
# 201  202  177.0    9.3        6.4   12.8      192.7
# 202  203  283.6   42.0       66.2   25.5      391.8
# 203  204  232.1    8.6        8.7   13.4      249.4
#
# [200 rows x 6 columns]

# %%
#b
x=df_marketing['TotalAdvt'].values.reshape(-1,1)
y=df_marketing['sales']
simple_model=linear_model.LinearRegression()
simple_model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
simple_model.score(x,y)#
#r square value
# Out:
# 0.7061969466330504

# %%
simple_model.coef_
#array of cofficient
# Out:
# array([0.05211182])

# %%
simple_model.intercept_
#intercept
# Out:
# 3.5842618027297153

# %%
plt.scatter(x,y,color='black')
plt.plot(x,simple_model.predict(x))

# %%
#from the above plot of simple regression model with the help of the regression line we
#can say that the with the increase in the adverting ,there is a increase in sales

# %%
#c
regr = skl_lm.LinearRegression()

X = df_marketing.sales.values.reshape(-1,1)
y = df_marketing.TotalAdvt

regr.fit(X,y)
print(regr.intercept_)
print(regr.coef_)
# Out:
# 10.883814271001057
# [13.55157012]

# %%
sales_pred = regr.predict(X)

# %%
sales_pred=regr.predict([[50000]])

# %%
sales_pred
# Out:
# array([677589.3895786])

# %%
#sales if total expenditure on advertising is rs 50000 is rs 677589

# %%
#d
x1=df_marketing.sales.values.reshape(-1,1)
y1=df_marketing.TotalAdvt
regr.fit(x1,y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(regr.fit(x1,y1))
print(regr.intercept_)
print(regr.coef_)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
# 10.883814271001057
# [13.55157012]

# %%
plt.scatter(x1,y1,color='black')
plt.plot(X,regr.predict(x1),color='blue')

# %%
#tas6
#a
tv=df_marketing['TV']
radio=df_marketing['radio']
newspaper=df_marketing['newspaper']
x1=np.stack((tv,radio,newspaper))
x1=x1.T
y1=df_marketing['sales']
multi_model=linear_model.LinearRegression()
multi_model.fit(x1,y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
multi_model.score(x1,y1)
#r square value
# Out:
# 0.8986348764209837

# %%
multi_model.coef_#coefficient as there are three variable so there are three array of cofficient
# Out:
# array([ 4.56811383e-02,  1.86739975e-01, -1.67488953e-04])

# %%
multi_model.intercept_
#iinterceot
# Out:
# 2.8835297721065505

# %%
#Task 6
#b (i)
#for TV 90000
regr = skl_lm.LinearRegression()

X = df_marketing.sales.values.reshape(-1,1)
y = df_marketing.TV

regr.fit(X,y)
print(regr.intercept_)
print(regr.coef_)
# Out:
# -1.5723837906357119
# [10.57278017]

# %%
sales_pred = regr.predict(X)

# %%
sales_pred=regr.predict([[90000]])

# %%
sales_pred
# Out:
# array([951548.64284319])

# %%
#for radio 3000
regr = skl_lm.LinearRegression()

X = df_marketing.sales.values.reshape(-1,1)
y = df_marketing.radio

regr.fit(X,y)
print(regr.intercept_)
print(regr.coef_)
# Out:
# -7.369026302585375
# [2.22654114]

# %%
sales_pred = regr.predict(X)
sales_pred=regr.predict([[3000]])

# %%
sales_pred
# Out:
# array([6672.25439251])

# %%
#for newspaper 45000
regr = skl_lm.LinearRegression()

X = df_marketing.sales.values.reshape(-1,1)
y = df_marketing.newspaper

regr.fit(X,y)
print(regr.intercept_)
print(regr.coef_)
# Out:
# 19.825224364222137
# [0.75224881]

# %%
sales_pred = regr.predict(X)

# %%
sales_pred=regr.predict([[45000]])

# %%
sales_pred
# Out:
# array([33871.02151665])

# %%
#b (ii)
#for tv 290000
regr = skl_lm.LinearRegression()

X = df_marketing.sales.values.reshape(-1,1)
y = df_marketing.TV

regr.fit(X,y)
print(regr.intercept_)
print(regr.coef_)
# Out:
# -1.5723837906357119
# [10.57278017]

# %%
sales_pred = regr.predict(X)
sales_pred=regr.predict([[290000]])

# %%
sales_pred
# Out:
# array([3066104.67668092])

# %%
#for newspaper 80000
regr = skl_lm.LinearRegression()

X = df_marketing.sales.values.reshape(-1,1)
y = df_marketing.newspaper

regr.fit(X,y)
print(regr.intercept_)
print(regr.coef_)
# Out:
# 19.825224364222137
# [0.75224881]

# %%
sales_pred = regr.predict(X)
sales_pred=regr.predict([[80000]])

# %%
sales_pred
# Out:
# array([60199.72974398])

# %%
#As we explain above predict method predict the future probability on the basis of given input. here only newspaper goes 
#in loss, or we can say that its stock market will decrease in future.
#predict method is used to determine stock market of any company on their input basis

# %%
#Task 6
#c
#for TV

regr = skl_lm.LinearRegression()

X = df_marketing.sales.values.reshape(-1,1)
y = df_marketing.TV

regr.fit(X,y)
print(regr.intercept_)
print(regr.coef_)
# Out:
# -1.5723837906357119
# [10.57278017]

# %%
sales_pred = regr.predict(X)
plt.scatter(X,y,color='black')
plt.plot(X,regr.predict(X),color='blue')

# %%
#for newspaper
regr = skl_lm.LinearRegression()

X = df_marketing.sales.values.reshape(-1,1)
y = df_marketing.newspaper

regr.fit(X,y)
print(regr.intercept_)
print(regr.coef_)
sales_pred = regr.predict(X)
# Out:
# 19.825224364222137
# [0.75224881]

# %%
plt.scatter(X,y,color='black')
plt.plot(X,regr.predict(X),color='blue',linewidth=3)

# %%
#for radio
regr = skl_lm.LinearRegression()

X = df_marketing.sales.values.reshape(-1,1)
y = df_marketing.radio

regr.fit(X,y)
print(regr.intercept_)
print(regr.coef_)
sales_pred = regr.predict(X)
# Out:
# -7.369026302585375
# [2.22654114]

# %%
plt.scatter(X,y,color='black')
plt.plot(X,regr.predict(X),color='blue',linewidth=3)

# %%
#Task 6
#d
#Both are calculated using predict method but one diferrence is that the option (c) use scatter plot to show how every 
#point varies with blue line, here we conclude that it is in the form of equation (y=mx+c) where y is dependent and x is 
#independent hence we can say that y represent blue line and x represent black point"""

# %%
#Task 7
#for simple model
regr = skl_lm.LinearRegression()

X = scale(df_marketing.sales, with_mean=True, with_std=False).reshape(-1,1)
y = df_marketing.TV

regr.fit(X,y)
print(regr.intercept_)
print(regr.coef_)
# Out:
# 147.821
# [10.57278017]

# %%
mean_squared_error(X, y)
# Out:
# 28477.29896

# %%
regr = skl_lm.LinearRegression()

X = df_marketing[['radio','newspaper', 'TV']].as_matrix()
y = df_marketing[['sales','radio','TV']].as_matrix()

regr.fit(X,y)
print(regr.coef_)
print(regr.intercept_)
# Out:
# [[ 1.86739975e-01 -1.67488953e-04  4.56811383e-02]
#  [ 1.00000000e+00  3.32795356e-16 -4.27653081e-17]
#  [-1.52930728e-16  5.00873896e-16  1.00000000e+00]]
# [ 2.88352977e+00  7.10542736e-15 -8.52651283e-14]
# C:\ProgramData\Anaconda\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %%
mean_squared_error(X,y)
# Out:
# 333.6899833333333

# %%
#Task 7
#a
x=df_marketing['TotalAdvt'].values.reshape(-1,1)
y=df_marketing['sales']
simple_model=linear_model.LinearRegression()
simple_model.fit(x,y)

simple_model.fit(x,y)
print(simple_model.intercept_)
print(simple_model.coef_)
# Out:
# 3.5842618027297153
# [0.05211182]

# %%
simple_y = simple_model.predict(x)
simple_y
# Out:
# array([27.16485915, 21.15115543, 10.30147506, 10.48386642, 16.6799615 ,
#        16.61221614, 10.49428878,  9.51458662, 11.47399095,  4.19397007,
#        15.23646416,  8.59220745, 16.23179987, 10.08781661,  9.43641889,
#        18.33190611, 19.00935974, 14.96548271, 23.21999458,  9.21233808,
#        13.50114064, 19.1917511 , 17.44600522,  7.68546183, 17.72740903,
#         8.44108318, 18.48303038, 13.21452565, 18.15993712, 19.15527283,
#        10.22330733, 22.57380804, 12.38594775, 10.2910527 , 18.48303038,
#        [5.99340152e+00, 1.21000000e+01, 1.87000000e+01],
#        [1.23619763e+01, 4.11000000e+01, 3.95000000e+01],
#        [8.34824251e+00, 1.08000000e+01, 7.55000000e+01],
#        [4.42958660e+00, 4.10000000e+00, 1.72000000e+01],
#        [1.83456196e+01, 4.20000000e+01, 1.66800000e+02],
#        [1.63689344e+01, 3.56000000e+01, 1.49700000e+02],
#        [5.31717581e+00, 3.70000000e+00, 3.82000000e+01],
#        [8.10036221e+00, 4.90000000e+00, 9.42000000e+01],
#        [1.27047011e+01, 9.30000000e+00, 1.77000000e+02],
#        [2.36706918e+01, 4.20000000e+01, 2.83600000e+02],
#        [1.50906286e+01, 8.60000000e+00, 2.32100000e+02]])

# %%
#Task 7
#b
#evaluating the prediction error
simple_model = skl_lm.LinearRegression()

X = df_marketing.sales.values.reshape(-1,1)
y = df_marketing.radio.values.reshape(-1,1)

simple_model.fit(X,y)

simple_mse=np.sqrt(mean_squared_error(X,y))
simple_mse
# Out:
# 18.803587423680618

# %%
#Evaluating the prediction error.
regr = skl_lm.LinearRegression()

X = df_marketing[['radio','newspaper', 'TV']].as_matrix()
y = df_marketing[['sales','radio','TV']].as_matrix()

regr.fit(X,y)

multi_mse = np.sqrt(mean_squared_error(X,y))
multi_mse
# Out:
# C:\ProgramData\Anaconda\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """
# 18.26718323478837

# %%
#Task 7
#c
#explaination of task 7
#The term "linearity" in algebra refers to a linear relationship between two or more variables. If we draw this relationship
#in a two dimensional space (between two variables, in this case), we get a straight line.
#Let's consider a scenario where we want to determine the linear relationship between the numbers of hours a student studies and
#the percentage of marks that student scores in an exam. We want to find out that given the number of hours a student prepares for
#a test, about how high of a score can the student achieve? If we plot the independent variable (hours) on the x-axis and 
#dependent variable (percentage) on the y-axis, linear regression gives us a straight line that best fits the data points,
#as shown in the figure below.
#We know that the equation of a straight line is basically:y = mx + b 
#Where b is the intercept and m is the slope of the line. So basically, the linear regression algorithm gives us the most optimal
#value for the intercept and the slope (in two dimensions). The y and x variables remain the same, since they are the data 
#features and cannot be changed. The values that we can control are the intercept and slope. There can be multiple straight
#lines depending upon the values of intercept and slope. Basically what the linear regression algorithm does is it fits multiple
#lines on the data points and returns the line that results in the least error.
#This same concept can be extended to the cases where there are more than two variables. This is called multiple linear 
#regression. For instance, consider a scenario where you have to predict the price of house based upon its area, number of 
#bedrooms, average income of the people in the area, the age of the house, and so on. In this case the dependent variable is
#dependent upon several independent variables. 
#A regression model involving multiple variables can be represented as: y = b0 + m1b1 + m2b2 + m3b3 + ... ... mnbn
#This is the equation of a hyper plane. Remember, a linear regression model in two dimensions is a straight line; in three
#dimensions it is a plane, and in more than three dimensions, 
#a hyper plane...

# %%
#which regression is better and why 
#Multi regression module is better because 
#y = b0 + m1b1 + m2b2 + m3b3 + ... ... mnbn
#as from above equation it is clear that it have only 1 dependent variable y and there are many independent variable bn.
#show we conclude that all data analysis at same time concatinating all data we analysis all data at at different vertex of plot.
#but simple regression model is also good on their own place because if we analysis only two data at same time,show by using 
#simple regression we find diferrence at every point, it clearify where it increase from the other data."""
